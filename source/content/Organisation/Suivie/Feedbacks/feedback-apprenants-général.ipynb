# %% [markdown]
# # Feedbacks Apprenants (Général)
#
# Ce Jupyter notebook est dédié a la gestion et au suivie des feedbacks des apprenants
#
# ## Process
#
# Chaque fin de semaine exporter le rapport (fichier excel), et lancer l'analyse
# - créer un rapport a envoyer au formateur

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Lire les fichier CSV
#
# ```{note}
#
#
#
# ```

# %%
# Le résultat du formulaire de feedbacks des apprenants

df_CDP1 = pd.read_csv('C:/Users/vdegu/3A_Alliance/Encyclopedia_3A/Viny_3A/TOPICS/Education/GROUND/SP-Label-Ecole/source/content/Organisation/Suivie/Feedbacks/data/data-07_02_25.csv')

df_test = pd.read_csv('C:/Users/vdegu/3A_Alliance/Encyclopedia_3A/Viny_3A/TOPICS/Education/GROUND/SP-Label-Ecole/source/content/Organisation/Suivie/Feedbacks/example/Feedback-CDP8.csv')

# Un tableau avec les noms prénoms des apprenant - créer une liste avec tout les prénoms

df_apprenants_CDP1 = pd.read_csv('C:/Users/vdegu/3A_Alliance/Encyclopedia_3A/Viny_3A/TOPICS/Education/GROUND/SP-Label-Ecole/source/content/Organisation/Suivie/Feedbacks/data/CDP-1_BDD_apprenants.csv')

# %% [markdown]
# ```{warning}
#
# De quels informations on a besoin et comment les extraire ?
#
# - nombre total apprenant
#
# - liste de tout les apprenants
# - liste de tout les cours
#
#
# ```

# %%
df_CDP1
# Out:
#                                     # Quel est ton nom de famille ?  \
# 0    8xaeoxm44l512xh7pi8xaeoxzkyzahee                       Schache
# 1    tz2z91cqhi4m8k24tz2ffz31d05qvj3k                       Schache
# 2    qzi032bzgya4q4jwqzi03ceica5osn7t                       Schache
# 3    ib59rvxf3cffcptgib59rveguqsl28cx                       Schache
# 4    gs8khb9i3smmy45jc8at8zggs8kh6o14                       Schache
# ..                                ...                           ...
# 250  4y8ql4z37l16c9q4mp64y8qllwx3jad1                       Seddiki
# 251  kg6z7m66qcvi2dxk4vtra5kg6z7mb8rh                       Seddiki
# 252  p8gddrxes0w0ysldrp8gd01jijwv843f                        Nguyen
# 253  w1ab0ka0t2n0kanx4brw1ab0kocxckby                    Boina-Maka
# 254  4lba7f2k7mzdr9wfiv4lba7f3gqjdn80                       SOUAIFI
#
#     Quel est ton prénom ?                 Quel module veux-tu renseigner ?   \
# 0                    Jana                                     HTML/ CSS/ JS
# 1                    Jana   Développer et optimiser son site sous WordPress
# 2                    Jana                        Droit de l'internet & RGPD
# 3                    Jana               Développer son réseau professionnel
# 4                    Jana                                     Soft skills 7
# ..                    ...                                               ...
# 250               Corinne  Comprendre l'impact du Marketing dans le digital
# 251               Corinne             Savoir réaliser un cahier des charges
# 252                  Anny                                     Soft skills 1
# 253                 Soula                                     Soft skills 2
# 254                Mahran                                     Soft skills 1
#
#     Comment te sens-tu à l'issue de ce module ?  Pourquoi ?  \
# 0                          J’ai beaucoup appris         NaN
# 1                          J’ai beaucoup appris         NaN
# 2                          J’ai beaucoup appris         NaN
# 3                          J’ai beaucoup appris         NaN
# 4                          J’ai beaucoup appris         NaN
# ..                                          ...         ...
# 250                        J’ai beaucoup appris         NaN
# 251                        J’ai beaucoup appris         NaN
# 252                        J’ai beaucoup appris         NaN
# 253                        J’ai beaucoup appris         NaN
# 254                        J’ai beaucoup appris         NaN
#
#     Le contenu  du module était-il adapté à tes attentes ? Pourquoi ?.1  \
# 0                                     Oui, tout à fait              NaN
# 1                                     Oui, tout à fait              NaN
# 2                                     Oui, tout à fait              NaN
# 3                                     Oui, tout à fait              NaN
# 4                                     Oui, tout à fait              NaN
# ..                                                 ...              ...
# 250                                   Oui, tout à fait              NaN
# 251                                   Oui, tout à fait              NaN
# 252                                   Oui, tout à fait              NaN
# 253                                   Oui, tout à fait              NaN
# 254                                        Oui, plutôt              NaN
#
#     As-tu le sentiment de maîtriser ce qui a été vu dans le module ?  \
# 0    Oui, j'ai tout compris ou presque (très bonne ...
# 1    Oui, j'ai tout compris ou presque (très bonne ...
# 2    Oui, j'ai tout compris ou presque (très bonne ...
# 3    Oui, j'ai tout compris ou presque (très bonne ...
# 4    Oui, j'ai tout compris ou presque (très bonne ...
# ..                                                 ...
# 250  Oui, même si je dois revoir certains points (m...
# 251  Oui, j'ai tout compris ou presque (très bonne ...
# 252  Oui, même si je dois revoir certains points (m...
# 253  Oui, même si je dois revoir certains points (m...
# 254  Oui, même si je dois revoir certains points (m...
#
#                                             Lesquels ?  ...  \
# 0                                                  NaN  ...
# 1                                                  NaN  ...
# 2                                                  NaN  ...
# 3                                                  NaN  ...
# 4                                                  NaN  ...
# ..                                                 ...  ...
# 250                                    Revoir le cours  ...
# 251                                                NaN  ...
# 252  La maîtrise nécessite de l’entraînement sur du...  ...
# 253                                  Prendre la parole  ...
# 254                     Parler en cercle ou au tableau  ...
#
#     Peux-tu partager une chose que tu as retenue de ce module ?  \
# 0    Le HTML (HyperText Markup Language) est le squ...
# 1    Plus de 40 % de tous les sites Web sur Interne...
# 2    Le RGPD est une loi européenne qui réglemente ...
# 3    Utilisez les plateformes de manière stratégiqu...
# 4    Des études montrent que les personnes qui prat...
# ..                                                 ...
# 250  Le e-commerce prend une place de plus en plus ...
# 251                            Simplicité à comprendre
# 252  J’ai adoré discuter des notions para langage /...
# 253                                      Varier le ton
# 254  L'importance de l'intonation de la voix, savoi...
#
#                    Comment as-tu trouvé le formateur ?  \
# 0    Mon Dieu, il nous met au défi d'atteindre notr...
# 1    se soucie véritablement de la réussite de ses ...
# 2    Un excellent retour sur l'enseignante : elle a...
# 3             renforcer la confiance en mes capacités.
# 4            rend l'apprentissage amusant et engageant
# ..                                                 ...
# 250                       Pédagogue, clair, à l'écoute
# 251                    Clair, précis, concis, agréable
# 252  Très investi et dynamique , axé sur la pratique .
# 253                                    Très compétente
# 254                                          Très bien
#
#              As-tu des idées pour améliorer le cours ?  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 250                                                Non
# 251                                                Non
# 252  Il y a eu beaucoup de sollicitation  active gr...
# 253                                            Aucunes
# 254                                                NaN
#
#                                   D’autres remarques ? Response Type  \
# 0                                                  NaN     completed
# 1                                                  NaN     completed
# 2                                                  NaN     completed
# 3                                                  NaN     completed
# 4                                                  NaN     completed
# ..                                                 ...           ...
# 250                                                Non     completed
# 251                                                Non     completed
# 252  Une présentation très utiles , intervenant qui...     completed
# 253                                            Aucunes     completed
# 254                                                NaN     completed
#
#         Start Date (UTC) Stage Date (UTC)    Submit Date (UTC)  Network ID  \
# 0    2025-02-06 18:42:42              NaN  2025-02-06 18:44:22  75854f4f33
# 1    2025-02-06 18:40:49              NaN  2025-02-06 18:42:23  75854f4f33
# 2    2025-02-06 18:38:13              NaN  2025-02-06 18:40:37  75854f4f33
# 3    2025-02-06 18:35:48              NaN  2025-02-06 18:38:00  75854f4f33
# 4    2025-02-06 18:33:18              NaN  2025-02-06 18:35:33  75854f4f33
# ..                   ...              ...                  ...         ...
# 250  2024-10-18 19:07:23              NaN  2024-10-18 19:10:01  c043ffa78e
# 251  2024-10-18 19:05:50              NaN  2024-10-18 19:07:15  c043ffa78e
# 252  2024-10-18 14:55:24              NaN  2024-10-18 15:36:11  513393caeb
# 253  2024-10-18 14:49:12              NaN  2024-10-18 14:54:58  2acc1a299c
# 254  2024-10-18 14:46:35              NaN  2024-10-18 14:49:11  4adfa917dd
#
#     Tags
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# ..   ...
# 250  NaN
# 251  NaN
# 252  NaN
# 253  NaN
# 254  NaN
#
# [255 rows x 21 columns]

# %% [markdown]
# ### Création des variables
#
# - Liste de tout les cours
# - liste de tout les élèves

# %%
liste_cours = df_test["Quel module veux-tu renseigner ? "].unique().tolist()

# %%
liste_cours
# Out:
# ['Bien démarrer sur Illustrator',
#  'Charte graphique',
#  "Comprendre le web et l'e-commerce",
#  "Concevoir l'interface (UI)",
#  'Concevoir la navigation (UX)',
#  'Connaître et maîtriser les principes et les règles du référencement naturel',
#  'Créer un support print sur Illustrator / PhotoShop',
#  'CV et Lettre de motivation',
#  'Développer et optimiser son site sous PrestaShop',
#  'Développer et optimiser son site sous WordPress',
#  "Droit de l'internet & RGPD",
#  'Exporter et diffuser une vidéo',
#  'HTML/ CSS/ JS',
#  'Introduction au webdesign',
#  "Maîtriser l'outil Google Slides",
#  "Maîtriser les bases d'Adobe PhotoShop",
#  'Maîtriser les bases de la photographie e-commerce',
#  'Montage vidéo',
#  "Savoir concevoir une campagne d'emailing",
#  'Savoir réaliser un cahier des charges (partie 1)',
#  'Savoir réaliser un cahier des charges (partie 2)',
#  'Soft skills 1',
#  'Soft Skills 2',
#  'Soft skills 3',
#  'Soft skills 4',
#  'Soft skills 5',
#  'Soft skills 6',
#  'Soft skills 7',
#  'Soft skills 8',
#  "Techniques et méthodes d'impression",
#  'Tests utilisateurs',
#  "UX/UI : Comprendre les utilisateurs pour scénariser l'UX",
#  'Veille sur internet']

# %%
liste_apprenants = df_apprenants_CDP1["Prénom"].unique().tolist()

# %%
liste_apprenants
# Out:
# ['Ranya',
#  'Anny',
#  'Salman',
#  'Yannis',
#  'Audrey',
#  'Adam',
#  'Mahran',
#  'Sylvia',
#  'Yassine',
#  'Corinne',
#  'Jana',
#  'Soula',
#  'Soidrou',
#  'Célica',
#  'Sophia',
#  'Christophe',
#  'Kanelle',
#  'Christian']

# %% [markdown]
# ## Analyse global
#
# ```{note}
#
# Générer un histogramme avec le nombre de réponses par module
# - Utiliser le
#
# - créer un diagramme matricielle qui nous montre un oui - non avec des couleurs différentes
#
# ```
#
# ### Créer un dictionnaire

# %%
# Créer un dictionnaire associant chaque cours aux étudiants ayant donné des réponses
feedback = df_CDP1.groupby("Quel module veux-tu renseigner ? ")["Quel est ton prénom ?"].apply(list).to_dict()

# %%
feedback
# Out:
# {'Bien démarrer illustrator partie 1': ['Jana',
#   'Christian',
#   'Mahran',
#   'Ranya',
#   'Sissi',
#   'Corinne',
#   'Sophia'],
#  'Bien démarrer illustrator partie 2': ['Jana',
#   'Christian',
#   'Ranya',
#   'Jana',
#   'Sissi',
#   'Mahran',
#   'Corinne',
#   'Audrey',
#   'Sophia'],
#  'Bien démarrer illustrator partie 3': ['Jana',
#   'Christian',
#   'Yassine',
#   'Ranya',
#   'Christian',
#   'Mahran',
#   'Sissi',
#   'Soula',
#   'Corinne'],
#  'Charte graphique': ['Jana',
#   'Christian',
#   'Sissi',
#   'Corinne',
#   'Audrey',
#   'Mahran',
#   'Soula',
#   'Anny'],
#  "Comprendre l'impact du Marketing dans le digital": ['Jana',
#   'Christian',
#   'Mahran',
#   'Ranya',
#   'Sylvia',
#   'Corinne'],
#  "Comprendre les utilisateurs pour scénariser l'UX": ['Jana',
#   'Christian',
#   'Mahran',
#   'Corinne'],
#  "Concevoir l'interface UI  partie 1": ['Jana',
#   'Christian',
#   'Mahran',
#   'Sophia',
#   'Ranya',
#   'Corinne',
#   'Christophe'],
#  "Concevoir l'interface UI partie 2": ['Jana',
#   'Christian.',
#   'Mahran',
#   'Ranya',
#   'Seddiki',
#   'Christophe'],
#  'Concevoir la navigation UX': ['Jana',
#   'Christian',
#   'Mahran',
#   'Corinne',
#   'Ranya',
#   'Sophia',
#   'Soula'],
#  'Créer un support Print sur illustrator': ['Jana',
#   'Soidrou',
#   'Christian',
#   'Mahran',
#   'Soula',
#   'Anny',
#   'Corinne'],
#  "Droit de l'internet & RGPD": ['Jana',
#   'Corinne',
#   'kanelle',
#   'Sophia',
#   'Mahran',
#   'Adam',
#   'Christian',
#   'Jana',
#   'Yassine',
#   'Sylvia',
#   'Ranya',
#   'Soula'],
#  'Développer et optimiser son site sous WordPress': ['Jana',
#   'Soidrou',
#   'Yassine',
#   'Yannis',
#   'Christian',
#   'Christian',
#   'Adam',
#   'Corinne',
#   'Mahran',
#   'Ranya',
#   'Anny',
#   'Soidrou',
#   'Soula'],
#  'Développer son réseau professionnel': ['Jana', 'Corinne', 'Soula'],
#  'Exporter et diffuser une vidéo': ['Jana', 'Christian', 'Mahran', 'Soula'],
#  'HTML/ CSS/ JS': ['Jana',
#   'Mahran',
#   'Yassine',
#   'Corinne',
#   'Ranya',
#   'Christian',
#   'Adam',
#   'Anny',
#   'Soula'],
#  'Introduction au webdesign': ['Jana', 'Christian.', 'Mahran', 'Soula'],
#  "Maîtriser l'outil Canva": ['Jana',
#   'Christian',
#   'Anny',
#   'Corinne',
#   'Soula',
#   'Audrey',
#   'Mahran',
#   'Yassine',
#   'Yannis'],
#  'Maîtriser les bases Adobe Photoshop 1': ['Jana',
#   'Christian',
#   'Sissi',
#   'Corinne',
#   'Mahran',
#   'Anny'],
#  'Maîtriser les bases Adobe Photoshop 2': ['Jana',
#   'Christian',
#   'Mahran',
#   'Corinne',
#   'Soula'],
#  'Maîtriser les bases de la photographie e-commerce': ['Jana',
#   'Christian',
#   'Mahran',
#   'Corinne',
#   'Soula'],
#  'Montage vidéo': ['Jana',
#   'Soidrou',
#   'Sylvia',
#   'Sophia',
#   'Ranya',
#   'Christian',
#   'Anny',
#   'Jana',
#   'Yassine',
#   'Audrey',
#   'Soula',
#   'Soidrou',
#   'Mahran'],
#  'Savoir réaliser un benchmark digital': ['Jana',
#   'Christian',
#   'Mahran',
#   'Sissi',
#   'Corinne',
#   'Soula',
#   'Corinne'],
#  'Savoir réaliser un cahier des charges': ['Jana',
#   'Christian',
#   'Adam',
#   'Mahran',
#   'Soula',
#   'Sophia',
#   'Kanelle',
#   'Ranya',
#   'Sylvia',
#   'Corinne'],
#  'Soft skills 1': ['Jana',
#   'test',
#   'Corinne',
#   'Christian',
#   'Kanelle',
#   'Ranya',
#   'Sophia',
#   'Sylvia',
#   'Corinne',
#   'Anny',
#   'Mahran'],
#  'Soft skills 2': ['Jana',
#   'Mahran',
#   'Christian',
#   'Corinne',
#   'Sophia',
#   'Audrey',
#   'Yassine',
#   'Soula'],
#  'Soft skills 3': ['Jana',
#   'Christian',
#   'Mahran',
#   'Christian',
#   'Christian',
#   'Ranya',
#   'Corinne',
#   'Sophia'],
#  'Soft skills 4': ['Jana',
#   'Christian',
#   'Mahran',
#   'Christian',
#   'Seddiki',
#   'Soula'],
#  'Soft skills 5': ['Jana',
#   'Jana',
#   'Adam',
#   'Christian',
#   'Mahran',
#   'Christian',
#   'Christian',
#   'Adam',
#   'Sylvia',
#   'Corinne',
#   'Ranya',
#   'Sophia',
#   'Soula'],
#  'Soft skills 6': ['Jana',
#   'Soidrou',
#   'Sylvia',
#   'Sophia',
#   'Ranya',
#   'Soula',
#   'Mahran',
#   'Corinne'],
#  'Soft skills 7': ['Jana', 'Mahran', 'Ranya', 'Corinne', 'Soula'],
#  'Storyboard': ['Jana', 'Christian.', 'Mahran', 'Soula', 'Sylvia', 'Corinne'],
#  "Techniques et méthodes d'impression": ['Jana'],
#  'Tests utilisateurs': ['Jana',
#   'Corinne',
#   'Yannis',
#   'Sophia',
#   'Soidrou',
#   'Yassine',
#   'Jana',
#   'Ranya',
#   'Mahran',
#   'Soula'],
#  'Veille sur internet': ['Jana',
#   'Christian',
#   'Mahran',
#   'Anny',
#   'Christophe',
#   'Ranya',
#   'Sophia',
#   'Sylvia',
#   'Corinne']}

# %% [markdown]
# ### Graph
#
# ```{note}
#
# Insérer la date du jour dans le titre
#
# ```

# %%
# Extraction des listes d'étudiants et de cours
etudiants = sorted({etudiant for etudiants_list in feedback.values() for etudiant in etudiants_list})
cours = sorted(feedback.keys())

# Matrice des couleurs (True si feedback trouvé, False sinon)
colors = np.zeros((len(etudiants), len(cours)), dtype=bool)

for i, etudiant in enumerate(etudiants):
    for j, cour in enumerate(cours):
        colors[i, j] = etudiant in feedback.get(cour, [])

# Création du diagramme
fig, ax = plt.subplots(figsize=(15, 9))
cmap = plt.cm.RdYlGn  # Rouge pour False, Vert pour True
im = ax.imshow(colors, cmap=cmap, interpolation='nearest')

# Configuration des axes
ax.set_xticks(np.arange(len(cours)))
ax.set_yticks(np.arange(len(etudiants)))
ax.set_xticklabels(cours)
ax.set_yticklabels(etudiants)

# Rotation des noms de colonnes (cours)
plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

# Ajout des valeurs dans les cases
for i in range(len(etudiants)):
    for j in range(len(cours)):
        text = "✔" if colors[i, j] else "✘"
        ax.text(j, i, text, ha="center", va="center", color="black")

# Titre et ajustement
ax.set_title("Feedbacks Apprenants 07/02/2025")
plt.savefig("feedbacks-apprenants-07-02-25.png", dpi=300, bbox_inches="tight")
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Post processing

# %%
# Afficher des statistiques descriptives
print(df_test.describe())

# Afficher les noms des colonnes
print(df_test.columns)
# Out:
#        Pourquoi ?
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN
# Index(['Quel est ton nom de famille ?', 'Quel est ton prénom ?',
#        'Quel module veux-tu renseigner ? ',
#        'Comment te sens-tu à l'issue de ce module ?', 'Pourquoi ?',
#        'Le contenu  du module était-il adapté à tes attentes ?',
#        'Pourquoi ?.1',
#        'As-tu le sentiment de maîtriser ce qui a été vu dans le module ?',
#        'Lesquels ?', 'Pourquoi ?.2',
#        'Peux-tu partager une chose que tu as retenue de ce module ?',
#        'Comment as-tu trouvé lea formateur.trice ?',
#        'As-tu des idées pour améliorer le cours ?', 'D’autres remarques ?',
#        'Submitted At', 'Token'],
#       dtype='object')

# %%
df_filtre = df_test[df_test['Quel module veux-tu renseigner ? '] == "Soft skills 1"]

# %%
#df_filtre

# %% [markdown]
# ## Résultats
#
# ### Pourcentage de réponse
#
# mettre nombre d'apprenants dans une variable

# %%
pourcentage = len(df_filtre) / 17 * 100

# %%
pourcentage
# Out:
# 82.35294117647058

# %% [markdown]
# ## Figures
#
# ### Comment te sens-tu à l'issue de ce module ?
#
# - histogramme / cammembert ?

# %%
valeurs_uniques = df_filtre["Comment te sens-tu à l'issue de ce module ?"].value_counts()
print(valeurs_uniques)
# Out:
# J’ai appris de manière satisfaisante    7
# J’ai beaucoup appris                    3
# Name: Comment te sens-tu à l'issue de ce module ?, dtype: int64

# %%
# Création d'un histogramme
valeurs_uniques.plot(kind='bar', color='skyblue', edgecolor='black')

# Ajouter un titre et des labels
plt.title('Résultat')
plt.xlabel('réponses')
plt.ylabel('Nombre de réponses')

# Afficher le graphique
plt.show()

# %% [markdown]
# ## Idée amélioration du feedback
#
# - Rajouter la date du cours,
#
# ```{note}
#
# peut-être l'inclure manuellement pour pas surcharger le formulaire
#
# ```

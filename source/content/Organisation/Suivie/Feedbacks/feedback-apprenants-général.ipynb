# %% [markdown]
# # Feedbacks Apprenants (Général)
#
# Ce Jupyter notebook est dédié a la gestion et au suivie des feedbacks des apprenants
#
# ## Process
#
# Chaque fin de semaine exporter le rapport (fichier excel), et lancer l'analyse
# - créer un rapport a envoyer au formateur

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Lire les fichier CSV
#
# ```{note}
# Actuellement, il faut télécharger les différentes données nécéssaires à l'execution de ce notebook.
#
# - Possibilité de récupérer directement les données depuis le drive ?
#
# ```

# %%
# Le résultat du formulaire de feedbacks des apprenants

#df_CDP1 = pd.read_csv('C:/Users/vdegu/3A_Alliance/Encyclopedia_3A/Viny_3A/TOPICS/Education/GROUND/SP-Label-Ecole/source/content/Organisation/Suivie/Feedbacks/data/data-07_02_25.csv')
df_CDP2 = pd.read_csv('C:/Users/vdegu/3A_Alliance/School_3A/Formations/SP-Label-Ecole/source/content/Organisation/Suivie/Feedbacks/data/CDP2/data-24_04_25.csv', encoding='latin1')

df_test = pd.read_csv('C:/Users/vdegu/3A_Alliance/School_3A/Formations/SP-Label-Ecole/source/content/Organisation/Suivie/Feedbacks/data/example/Feedback-CDP8.csv')

# Un tableau avec les noms prénoms des apprenant - créer une liste avec tout les prénoms

df_apprenants_CDP2 = pd.read_csv('C:/Users/vdegu/3A_Alliance/School_3A/Formations/SP-Label-Ecole/source/content/Organisation/Suivie/Feedbacks/data/CDP2/CDP2-BDD.csv', encoding='latin1')

# %% [markdown]
# ```{warning}
#
# De quels informations on a besoin et comment les extraire ?
#
# - nombre total apprenant
#
# - liste de tout les apprenants
# - liste de tout les cours
#
#
# ```

# %%
df_CDP2
# Out:
#                                    # Quel est ton nom de famille ?  \
# 0   y4fydk7xanp6a96equgv51y4fyd8caeb                     DRISSAOUI
# 1   sw0tfwy2idq7j2ylehlzdsw0tfwyghyl                         ALLAL
# 2   v6bc2gutzzcu8bi6v6bc2rmvqr9wjy15                  Douma Garcia
# 3   oafuzd0s5gd23nh0ob4oafuar32298er                      Abdallah
# 4   llab57y5wlu6k423qymllab5i6jh1xqx                       Szklorz
# 5   rp81udn2np812omrp81nczbmndt3lrc9                      Abdallah
# 6   rldrtzcb6e0umg5phrldrtz6wmgpnt7e                        Azaiez
# 7   y0epb5v1txw8iw7mum80py0epb5v9lbd                        Azaiez
# 8   urekwlz9vvs66surp93r4w4x2xayb3jv                     DRISSAOUI
# 9   vr2zziiukq7qlcmhfvr2z45oai7fvp6i                           Roy
# 10  8h28zauvlowq5b132kaij8h28zau88we                   Biancarelli
# 11  1nmcf8jxucgz7bdug1nmcfcpn3dwri2u                       Amdouni
# 12  99brrsomw4fd2f99s4sb17u9u6cbbof4                   Biancarelli
# 13  zp3bahknsdsbuj8ko8b3l8kzp3bahk2p                       Amdouni
# 14  dgvivi2p1822khxwtdgvie697zjjkyuc                           Roy
# 15  piun73lmjdgyvtnigpiun7wthf4coidq                           Roy
# 4       Jâai appris de maniÃ¨re satisfaisante         NaN
# 5                        Jâai beaucoup appris         NaN
# 6                        Jâai beaucoup appris         NaN
# 7       Jâai appris de maniÃ¨re satisfaisante         NaN
# 8                        Jâai beaucoup appris         NaN
# 9       Jâai appris de maniÃ¨re satisfaisante         NaN
# 10      Jâai appris de maniÃ¨re satisfaisante         NaN
# 11                       Jâai beaucoup appris         NaN
# 12      Jâai appris de maniÃ¨re satisfaisante         NaN
# 13                       Jâai beaucoup appris         NaN
# 14      Jâai appris de maniÃ¨re satisfaisante         NaN
# 15               Je n'ai pas appris grand-chose         NaN
# 16                       Jâai beaucoup appris         NaN
# 17                       Jâai beaucoup appris         NaN
# 18      Jâai appris de maniÃ¨re satisfaisante         NaN
# 19                       Jâai beaucoup appris         NaN
# 20                       Jâai beaucoup appris         NaN
# 21               Je n'ai pas appris grand-chose         NaN
# 22                       Jâai beaucoup appris         NaN
# 23      Jâai appris de maniÃ¨re satisfaisante         NaN
# 24      Jâai appris de maniÃ¨re satisfaisante         NaN
# 25                       Jâai beaucoup appris         NaN
# 26                       Jâai beaucoup appris         NaN
# 27                       Jâai beaucoup appris         NaN
# 28                       Jâai beaucoup appris         NaN
# 29      Jâai appris de maniÃ¨re satisfaisante         NaN
#
#    Le contenu  du module Ã©tait-il adaptÃ© Ã  tes attentes ?  \
# 0                                   Oui, tout Ã  fait
# 1                                                 NaN
# 2                                        Oui, plutÃ´t
# 3                                        Oui, plutÃ´t
# 4                                        Oui, plutÃ´t
# 5                                        Oui, plutÃ´t
# 6                                   Oui, tout Ã  fait
# 7                                        Oui, plutÃ´t
# 8                                   Oui, tout Ã  fait
# 9                                        Oui, plutÃ´t
# 10                                       Oui, plutÃ´t
# 11                                  Oui, tout Ã  fait
# 12                                       Oui, plutÃ´t
# 13                                  Oui, tout Ã  fait
# 14                                       Oui, plutÃ´t
# 15                                                NaN
# 16                                  Oui, tout Ã  fait
# 17                                       Oui, plutÃ´t
# 18                                       Oui, plutÃ´t
# 19                                  Oui, tout Ã  fait
# 20                                  Oui, tout Ã  fait
# 21                                                NaN
# 22                                  Oui, tout Ã  fait
# 23                                       Oui, plutÃ´t
# 24                                  Oui, tout Ã  fait
# 25                                  Oui, tout Ã  fait
# 26                                  Oui, tout Ã  fait
# 27                                       Oui, plutÃ´t
# 28                                       Oui, plutÃ´t
# 29                                  Oui, tout Ã  fait
#
#                                    Pourquoi ?.1  \
# 0                                           NaN
# 1                      Manques de cas pratiques
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                          NaN
# 14                                          NaN
# 15  Je nâai pas compris la structure du cours
# 16                                          NaN
# 17                                          NaN
# 18                                          NaN
# 19                                          NaN
# 20                                          NaN
# 21                               Jâai connais
# 22                                          NaN
# 23                                          NaN
# 24                                          NaN
# 25                                          NaN
# 26                                          NaN
# 27                                          NaN
# 28                                          NaN
# 29                                          NaN
#
#    As-tu le sentiment de maÃ®triser ce qui a Ã©tÃ© vu dans le module ?  \
# 0   Oui, j'ai tout compris ou presque (trÃ¨s bonne...
# 1   Non, je n'ai pas bien compris (maÃ®trise insuf...
# 2   Oui, mÃªme si je dois revoir certains points (...
# 3   Oui, mÃªme si je dois revoir certains points (...
# 4   Oui, j'ai tout compris ou presque (trÃ¨s bonne...
# 5   Oui, mÃªme si je dois revoir certains points (...
# 6   Oui, mÃªme si je dois revoir certains points (...
# 7   Oui, j'ai tout compris ou presque (trÃ¨s bonne...
# 8   Oui, j'ai tout compris ou presque (trÃ¨s bonne...
# 9   Oui, j'ai tout compris ou presque (trÃ¨s bonne...
# 10  Oui, j'ai tout compris ou presque (trÃ¨s bonne...
# 11  Oui, j'ai tout compris ou presque (trÃ¨s bonne...
# 12  Oui, j'ai tout compris ou presque (trÃ¨s bonne...
# 13  Oui, j'ai tout compris ou presque (trÃ¨s bonne...
# 14  Oui, j'ai tout compris ou presque (trÃ¨s bonne...
# 15  Non, je n'ai pas bien compris (maÃ®trise insuf...
# 16  Oui, j'ai tout compris ou presque (trÃ¨s bonne...
# 17  Oui, mÃªme si je dois revoir certains points (...
# 18  Oui, mÃªme si je dois revoir certains points (...
# 19  Oui, j'ai tout compris ou presque (trÃ¨s bonne...
# 20  Oui, j'ai tout compris ou presque (trÃ¨s bonne...
# 21  Oui, j'ai tout compris ou presque (trÃ¨s bonne...
# 22  Oui, j'ai tout compris ou presque (trÃ¨s bonne...
# 23  Oui, j'ai tout compris ou presque (trÃ¨s bonne...
# 24  Oui, mÃªme si je dois revoir certains points (...
# 25  Oui, j'ai tout compris ou presque (trÃ¨s bonne...
# 26  Oui, j'ai tout compris ou presque (trÃ¨s bonne...
# 27  Oui, j'ai tout compris ou presque (trÃ¨s bonne...
# 28  Oui, mÃªme si je dois revoir certains points (...
# 29  Oui, j'ai tout compris ou presque (trÃ¨s bonne...
#
#                                            Lesquels ?  ...  \
# 0                                                 NaN  ...
# 1                                                 NaN  ...
# 2                                                 NaN  ...
# 3                                                 NaN  ...
# 4                                                 NaN  ...
# 5                                                 NaN  ...
# 6                                                 NaN  ...
# 7                                                 NaN  ...
# 8                                                 NaN  ...
# 9                                                 NaN  ...
# 10                                                NaN  ...
# 11                                                NaN  ...
# 12                                                NaN  ...
# 13                                                NaN  ...
# 14                                                NaN  ...
# 15                                                NaN  ...
# 16                                                NaN  ...
# 17  AmÃ©liorer ma diction \nMieux gÃ©rer le stress...  ...
# 18                          La faÃ§on de sâexprimer  ...
# 19                                                NaN  ...
# 20                                                NaN  ...
# 21                                                NaN  ...
# 22                                                NaN  ...
# 23                                                NaN  ...
# 24                                   Les dÃ©finitions  ...
# 25                                                NaN  ...
# 26                                                NaN  ...
# 27                                                NaN  ...
# 28                                   Btob btoC etc...  ...
# 29                                                NaN  ...
#
#    Peux-tu partager une chose que tu as retenue de ce module ?  \
# 0                                           Push/pull
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                       Techniques de prise de parole
# 5                                                 NaN
# 6                                            Accroche
# 7                                        Para-verbale
# 8   Laisser des pause par moment pour permettre a ...
# 9           Jâai appris comment bien faire un pitch
# 10  J'ai essayÃ© de faire le maximum pour parler e...
# 11                  La respiration \nLa communication
# 12                                                NaN
# 13                                          Confience
# 14  On a travaillÃ© sur la respiration et je sais ...
# 15             Ce quâest le header dâune page web
# 16  Les diffÃ©rentes compÃ©tences a associer pour ...
# 17                           Comment parler en public
# 18                              Apprendre Ã  respirer
# 19  La diffÃ©rence entre le brief et le cahier des...
# 20                     Que Ã§a chauffe le crÃ¢ne ð
#
# 21                                             Qqqocp
# 22                                            Seo/Sea
# 23         Ce que doit contenir un cahier des charges
# 24  Les stratÃ©gie de vente et le systÃ¨me de rÃ©f...
# 25                                            Seo Sea
# 26             Le jargon et vocabulaire du e commerce
# 27                                      Les mots clÃ©
# 28                           La complexitÃ© d'un site
# 29  Lâanalyse dâaudience qui permet de savoir ...
#
#                  Comment as-tu trouvÃ© le formateur ?  \
# 0                                               10/10
# 1                                        Bienveillant
# 2                                                 NaN
# 3                                                 NaN
# 4                                       Assez prÃ©cis
# 5                                                 NaN
# 6                              TrÃ¨s bien et patiente
# 7                                           Pedagogue
# 8               10/10 bonne Ã©nergie bonne pÃ©dagogie
# 9                                          TrÃ¨s bien
# 10                                TrÃ¨s encourageante
# 11                                                Top
# 12  Quelques mots peut Ãªtre mal placÃ© ou maladro...
# 29                          NaN     completed  2025-04-14 14:45:21
#
#    Stage Date (UTC)    Submit Date (UTC)  Network ID Tags
# 0               NaN  2025-04-23 17:04:50  3792cf69fa  NaN
# 1               NaN  2025-04-23 15:23:08  c23cc5bac4  NaN
# 2               NaN  2025-04-22 15:52:13  892f729f87  NaN
# 3               NaN  2025-04-22 08:00:10  858ae67a41  NaN
# 4               NaN  2025-04-22 08:00:21  4adfa917dd  NaN
# 5               NaN  2025-04-22 07:58:19  858ae67a41  NaN
# 6               NaN  2025-04-18 17:06:39  e2cd7999ad  NaN
# 7               NaN  2025-04-18 17:04:24  e2cd7999ad  NaN
# 8               NaN  2025-04-18 16:49:03  e46a064306  NaN
# 9               NaN  2025-04-18 16:29:25  b0736ecb73  NaN
# 10              NaN  2025-04-18 16:26:53  43184166ac  NaN
# 11              NaN  2025-04-18 16:27:51  9f78c2ed85  NaN
# 12              NaN  2025-04-18 16:25:56  43184166ac  NaN
# 13              NaN  2025-04-18 16:25:06  9f78c2ed85  NaN
# 14              NaN  2025-04-17 17:58:27  4230759cb7  NaN
# 15              NaN  2025-04-17 17:56:45  4230759cb7  NaN
# 16              NaN  2025-04-17 16:35:54  f0aa060d64  NaN
# 17              NaN  2025-04-17 16:19:23  a8cf0b040c  NaN
# 18              NaN  2025-04-17 15:05:49  0c3cae9142  NaN
# 19              NaN  2025-04-17 09:10:43  db0e0992ee  NaN
# 20              NaN  2025-04-17 09:00:53  4adfa917dd  NaN
# 21              NaN  2025-04-17 09:02:11  4adfa917dd  NaN
# 22              NaN  2025-04-17 08:59:36  4adfa917dd  NaN
# 23              NaN  2025-04-15 15:58:48  8dab4bafc1  NaN
# 24              NaN  2025-04-15 08:31:50  5e18087af4  NaN
# 25              NaN  2025-04-14 17:56:55  9f78c2ed85  NaN
# 26              NaN  2025-04-14 16:45:32  e8303a6170  NaN
# 27              NaN  2025-04-14 15:30:10  556b0bb459  NaN
# 28              NaN  2025-04-14 15:06:21  4e863fcb02  NaN
# 29              NaN  2025-04-14 14:49:48  e0b8e56cad  NaN
#
# [30 rows x 21 columns]

# %% [markdown]
# ### Création des variables
#
# - Liste de tout les cours
# - liste de tout les élèves

# %%
liste_cours = df_test["Quel module veux-tu renseigner ? "].unique().tolist()

# %%
liste_cours
# Out:
# ['Bien démarrer sur Illustrator',
#  'Charte graphique',
#  "Comprendre le web et l'e-commerce",
#  "Concevoir l'interface (UI)",
#  'Concevoir la navigation (UX)',
#  'Connaître et maîtriser les principes et les règles du référencement naturel',
#  'Créer un support print sur Illustrator / PhotoShop',
#  'CV et Lettre de motivation',
#  'Développer et optimiser son site sous PrestaShop',
#  'Développer et optimiser son site sous WordPress',
#  "Droit de l'internet & RGPD",
#  'Exporter et diffuser une vidéo',
#  'HTML/ CSS/ JS',
#  'Introduction au webdesign',
#  "Maîtriser l'outil Google Slides",
#  "Maîtriser les bases d'Adobe PhotoShop",
#  'Maîtriser les bases de la photographie e-commerce',
#  'Montage vidéo',
#  "Savoir concevoir une campagne d'emailing",
#  'Savoir réaliser un cahier des charges (partie 1)',
#  'Savoir réaliser un cahier des charges (partie 2)',
#  'Soft skills 1',
#  'Soft Skills 2',
#  'Soft skills 3',
#  'Soft skills 4',
#  'Soft skills 5',
#  'Soft skills 6',
#  'Soft skills 7',
#  'Soft skills 8',
#  "Techniques et méthodes d'impression",
#  'Tests utilisateurs',
#  "UX/UI : Comprendre les utilisateurs pour scénariser l'UX",
#  'Veille sur internet']

# %%
liste_apprenants = df_apprenants_CDP2["Prénom"].unique().tolist()

# %%
liste_apprenants
# Out:
# ['Soumaya',
#  'Nouha',
#  'Enza',
#  'Zaccaria',
#  'Rafik Mohamed',
#  'Marwan',
#  'Houssam',
#  'Manon',
#  'Mehdi',
#  'Mohammed',
#  'Sofiane',
#  'Elodie',
#  'Laszlo',
#  'Fahar-Dine',
#  'Amar']

# %% [markdown]
# ## Analyse global
#
# ```{note}
#
# Générer un histogramme avec le nombre de réponses par module
# - Utiliser le
#
# - créer un diagramme matricielle qui nous montre un oui - non avec des couleurs différentes
#
# ```
#
# ### Créer un dictionnaire

# %%
# Créer un dictionnaire associant chaque cours aux étudiants ayant donné des réponses
feedback = df_CDP2.groupby("Quel module veux-tu renseigner ? ")["Quel est ton prÃ©nomâ¯?"].apply(list).to_dict()

# %%
feedback
# Out:
# {"Comprendre l'impact du Marketing dans le digital": ['Nouha',
#   'Enza',
#   'Soumaya',
#   'Mehdi',
#   'Mohammed',
#   'Elodie',
#   'Zaccaria'],
#  'Savoir rÃ©aliser un cahier des charges': ['Manon',
#   'Mehdi',
#   'Elodie',
#   'Soumaya',
#   'Mohammed'],
#  'Soft skills 1': ['Fahar-Dine',
#   'Nouha',
#   'Elodie',
#   'Soumaya',
#   'Manon',
#   'Mohammed',
#   'Mehdi',
#   'Amar'],
#  'Soft skills 2': ['Enza',
#   'Fahar-Dine',
#   'Laszlo',
#   'Nouha',
#   'Mohammed',
#   'Manon',
#   'Ã\x89lodie',
#   'Soumaya'],
#  'Veille sur internet': ['Mohammed', 'Mehdi']}

# %% [markdown]
# ### Graph
#
# ```{note}
#
# Insérer la date du jour dans le titre
#
# ```

# %%
# Extraction des listes d'étudiants et de cours
etudiants = sorted({etudiant for etudiants_list in feedback.values() for etudiant in etudiants_list})
cours = sorted(feedback.keys())

# Matrice des couleurs (True si feedback trouvé, False sinon)
colors = np.zeros((len(etudiants), len(cours)), dtype=bool)

for i, etudiant in enumerate(etudiants):
    for j, cour in enumerate(cours):
        colors[i, j] = etudiant in feedback.get(cour, [])

# Création du diagramme
fig, ax = plt.subplots(figsize=(15, 9))
cmap = plt.cm.RdYlGn  # Rouge pour False, Vert pour True
im = ax.imshow(colors, cmap=cmap, interpolation='nearest')

# Configuration des axes
ax.set_xticks(np.arange(len(cours)))
ax.set_yticks(np.arange(len(etudiants)))
ax.set_xticklabels(cours)
ax.set_yticklabels(etudiants)

# Rotation des noms de colonnes (cours)
plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

# Ajout des valeurs dans les cases
for i in range(len(etudiants)):
    for j in range(len(cours)):
        text = "✔" if colors[i, j] else "✘"
        ax.text(j, i, text, ha="center", va="center", color="black")

# Titre et ajustement
ax.set_title("Feedbacks Apprenants 24/04/2025")
plt.savefig("Resultats/feedbacks-apprenants-24-04-25.png", dpi=300, bbox_inches="tight")
fig.tight_layout()
plt.show()
# Out:
# C:\Users\vdegu\AppData\Local\Temp\ipykernel_23548\2958650036.py:34: UserWarning: Glyph 137 (\x89) missing from font(s) DejaVu Sans.
#   plt.savefig("Resultats/feedbacks-apprenants-24-04-25.png", dpi=300, bbox_inches="tight")
# C:\Users\vdegu\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 137 (\x89) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### To do
#
# - Insérer la date en début de notebook

# %% [markdown]
# ## Post processing

# %%
# Afficher des statistiques descriptives
print(df_test.describe())

# Afficher les noms des colonnes
print(df_test.columns)
# Out:
#        Pourquoi ?
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN
# Index(['Quel est ton nom de famille ?', 'Quel est ton prénom ?',
#        'Quel module veux-tu renseigner ? ',
#        'Comment te sens-tu à l'issue de ce module ?', 'Pourquoi ?',
#        'Le contenu  du module était-il adapté à tes attentes ?',
#        'Pourquoi ?.1',
#        'As-tu le sentiment de maîtriser ce qui a été vu dans le module ?',
#        'Lesquels ?', 'Pourquoi ?.2',
#        'Peux-tu partager une chose que tu as retenue de ce module ?',
#        'Comment as-tu trouvé lea formateur.trice ?',
#        'As-tu des idées pour améliorer le cours ?', 'D’autres remarques ?',
#        'Submitted At', 'Token'],
#       dtype='object')

# %%
df_filtre = df_test[df_test['Quel module veux-tu renseigner ? '] == "Soft skills 1"]

# %%
#df_filtre

# %% [markdown]
# ## Résultats
#
# ### Pourcentage de réponse
#
# mettre nombre d'apprenants dans une variable

# %%
pourcentage = len(df_filtre) / 17 * 100

# %%
pourcentage
# Out:
# 82.35294117647058

# %% [markdown]
# ## Figures
#
# ### Comment te sens-tu à l'issue de ce module ?
#
# - histogramme / cammembert ?

# %%
valeurs_uniques = df_filtre["Comment te sens-tu à l'issue de ce module ?"].value_counts()
print(valeurs_uniques)
# Out:
# Comment te sens-tu à l'issue de ce module ?
# J’ai appris de manière satisfaisante    10
# Je n'ai pas appris grand-chose           2
# J’ai beaucoup appris                     2
# Name: count, dtype: int64

# %%
# Création d'un histogramme
valeurs_uniques.plot(kind='bar', color='skyblue', edgecolor='black')

# Ajouter un titre et des labels
plt.title('Résultat')
plt.xlabel('réponses')
plt.ylabel('Nombre de réponses')

# Afficher le graphique
plt.show()

# %% [markdown]
# ## Idée amélioration du feedback
#
# - Rajouter la date du cours,
#
# ```{note}
#
# peut-être l'inclure manuellement pour pas surcharger le formulaire
#
# ```
